# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\rense\Downloads\ev_charging_patterns.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3              108.463007         Station_391
# 1        User_2  Hyundai Kona              100.000000         Station_428
# 2        User_3    Chevy Bolt               75.000000         Station_181
# 3        User_4  Hyundai Kona               50.000000         Station_327
# 4        User_5  Hyundai Kona               50.000000         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location Charging Start Time Charging End Time  \
# ...

# %%
df.head()
# Out:
#   User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0  User_1        BMW i3              108.463007         Station_391
# 1  User_2  Hyundai Kona              100.000000         Station_428
# 2  User_3    Chevy Bolt               75.000000         Station_181
# 3  User_4  Hyundai Kona               50.000000         Station_327
# 4  User_5  Hyundai Kona               50.000000         Station_108
#
#   Charging Station Location Charging Start Time Charging End Time  \
# 0                   Houston    01-01-2024 00:00  01-01-2024 00:39
# 1             San Francisco    01-01-2024 01:00  01-01-2024 03:01
# 2             San Francisco    01-01-2024 02:00  01-01-2024 04:48
# 3                   Houston    01-01-2024 03:00  01-01-2024 06:42
# 4               Los Angeles    01-01-2024 04:00  01-01-2024 05:46
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# ...

# %%
print(df.to_string())
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID Charging Station Location Charging Start Time Charging End Time  Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  State of Charge (End %)  Distance Driven (since last charge) (km)  Temperature (°C)  Vehicle Age (years)     Charger Type               User Type
# 0        User_1         BMW i3              108.463007         Station_391                   Houston    01-01-2024 00:00  01-01-2024 00:39              60.712346                   0.591363           36.389181            13.087717     Evening     Tuesday                  29.371576                86.119962                                293.602111         27.947953             2.000000  DC Fast Charger                Commuter
# ...

# %%
df_backup=df.copy()

# %%
df_backup
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3              108.463007         Station_391
# 1        User_2  Hyundai Kona              100.000000         Station_428
# 2        User_3    Chevy Bolt               75.000000         Station_181
# 3        User_4  Hyundai Kona               50.000000         Station_327
# 4        User_5  Hyundai Kona               50.000000         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location Charging Start Time Charging End Time  \
# ...

# %%
df.describe()
# Out:
#        Battery Capacity (kWh)  Energy Consumed (kWh)  \
# count             1320.000000            1254.000000
# mean                74.534692              42.642894
# std                 20.626914              22.411705
# min                  1.532807               0.045772
# 25%                 62.000000              23.881193
# 50%                 75.000000              42.691405
# 75%                 85.000000              61.206218
# max                193.003074             152.238758
#
#        Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# count                1320.000000         1254.000000          1320.000000
# mean                    2.269377           25.963003            22.551352
# std                     1.061037           14.011326            10.751494
# min                     0.095314            1.472549             0.234317
# 25%                     1.397623           13.856583            13.368141
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User ID                                   1320 non-null   object
#  1   Vehicle Model                             1320 non-null   object
#  2   Battery Capacity (kWh)                    1320 non-null   float64
#  3   Charging Station ID                       1320 non-null   object
#  4   Charging Station Location                 1320 non-null   object
#  5   Charging Start Time                       1320 non-null   object
#  6   Charging End Time                         1320 non-null   object
#  7   Energy Consumed (kWh)                     1254 non-null   float64
#  8   Charging Duration (hours)                 1320 non-null   float64
#  9   Charging Rate (kW)                        1254 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# User ID                                      0
# Vehicle Model                                0
# Battery Capacity (kWh)                       0
# Charging Station ID                          0
# Charging Station Location                    0
# Charging Start Time                          0
# Charging End Time                            0
# Energy Consumed (kWh)                       66
# Charging Duration (hours)                    0
# Charging Rate (kW)                          66
# Charging Cost (USD)                          0
# Time of Day                                  0
# Day of Week                                  0
# State of Charge (Start %)                    0
# State of Charge (End %)                      0
# Distance Driven (since last charge) (km)    66
# Temperature (°C)                             0
# Vehicle Age (years)                          0
# Charger Type                                 0
# User Type                                    0
# dtype: int64

# %%
for col in df:
    if df[col].dtype=='float64':
        df[col]=df[col].interpolate(method='polynomial',order=5)
        print(col)
# Out:
# Battery Capacity (kWh)
# Energy Consumed (kWh)
# Charging Duration (hours)
# Charging Rate (kW)
# Charging Cost (USD)
# State of Charge (Start %)
# State of Charge (End %)
# Distance Driven (since last charge) (km)
# Temperature (°C)
# Vehicle Age (years)

# %% [markdown]
# # 1.What is the average energy consumed per charging session?

# %%
average_energy_consumed = df['Energy Consumed (kWh)'].mean()
print(average_energy_consumed)
# Out:
# 42.91774956654133

# %% [markdown]
# # Conclusion
# The average energy consumed per charging session is approximately X kWh (replace X with the actual value from the code output), which reflects the typical energy usage for each charging event in this dataset.

# %% [markdown]
# # 2. Which vehicle model has the highest average battery capacity?

# %%
avg_battery_capacity_by_model = df.groupby('Vehicle Model')['Battery Capacity (kWh)'].mean().idxmax()
avg_battery_capacity_by_model
# Out:
# 'BMW i3'

# %% [markdown]
# # Conclusion
# The vehicle model with the highest average battery capacity is [Vehicle Model Name] (replace with the actual model from the code output).

# %% [markdown]
# # 3. What is the total charging cost for all users?

# %%
total_charging_cost = df['Charging Cost (USD)'].sum()
print(total_charging_cost)
# Out:
# 29767.784307011

# %% [markdown]
# # Conclusion
# The total charging cost for all users is $X (replace X with the actual value), representing the total amount spent on charging sessions in the dataset.

# %% [markdown]
# # 4.What is the distribution of users based on the charger type?

# %%
total_charging_cost = df['Charging Cost (USD)'].sum()
print(total_charging_cost)
# Out:
# 29767.784307011

# %% [markdown]
# # Conclusion
# The distribution of users varies across different charger types, with [most common charger type] being the most frequently used (replace with actual value from the code).

# %% [markdown]
# # 5. How does the average charging duration vary based on user type?

# %%
avg_charging_duration_by_user_type = df.groupby('User Type')['Charging Duration (hours)'].mean()
avg_charging_duration_by_user_type
# Out:
# User Type
# Casual Driver             2.284515
# Commuter                  2.305164
# Long-Distance Traveler    2.216299
# Name: Charging Duration (hours), dtype: float64

# %% [markdown]
# # Conclusion
# The average charging duration varies by user type, with [user type with the highest duration] having the longest average charging sessions (replace with the actual user type from the code output)

# %% [markdown]
# # 6.What is the most common vehicle model in the dataset?

# %%
most_common_vehicle_model =df['Vehicle Model'].value_counts().idxmax()
most_common_vehicle_model
# Out:
# 'Tesla Model 3'

# %% [markdown]
# # Conclusion
# The most common vehicle model in the dataset is [Vehicle Model Name] (replace with the actual model from the code output)

# %% [markdown]
# # 7.What is the average state of charge at the start and end of charging?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming you've already calculated these values
avg_soc_start = df['State of Charge (Start %)'].mean()
avg_soc_end = df['State of Charge (End %)'].mean()

# Data for the plot
soc_data = pd.DataFrame({
    'SOC Stage': ['Start SOC (%)', 'End SOC (%)'],
    'Average SOC (%)': [avg_soc_start, avg_soc_end]
})

# Set the style of seaborn plot
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='SOC Stage', y='Average SOC (%)', data=soc_data, palette='Blues')

# Add labels and title
plt.title('Average State of Charge (Start vs End)', fontsize=14)
plt.ylabel('State of Charge (%)')
plt.ylim(0, 100)  # Limit the y-axis to the range of SOC percentages

# Show the plot
plt.show()
# Out:
# C:\Users\rense\AppData\Local\Temp\ipykernel_16304\443656207.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='SOC Stage', y='Average SOC (%)', data=soc_data, palette='Blues')

# %% [markdown]
# # Conclusion
#  The average State of Charge (SOC) at the start of charging sessions is approximately 48.67%, and the SOC at the end of charging is around 79.86%

# %% [markdown]
# # 8.Which charging station location has the highest total energy consumption?

# %%
highest_energy_location = df.groupby('Charging Station Location')['Energy Consumed (kWh)'].sum().idxmax()
highest_energy_location
# Out:
# 'Los Angeles'

# %% [markdown]
# # Conclusion
# The charging station location with the highest total energy consumption is [Charging Station Location] (replace with the actual location from the code output).

# %% [markdown]
# # 9.What is the average temperature during charging sessions for different charger types?

# %%
avg_temp_by_charger = df.groupby('Charger Type')['Temperature (°C)'].mean()
print(avg_temp_by_charger)
# Out:
# Charger Type
# DC Fast Charger    15.002376
# Level 1            15.374664
# Level 2            15.405912
# Name: Temperature (°C), dtype: float64

# %% [markdown]
# # Conclusion
# The average temperature during charging sessions varies by charger type, with [Charger Type] experiencing the highest average temperature (replace with actual charger type from the code output).

# %% [markdown]
# # 10.What is the distribution of charging sessions across different days of the week?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of charging sessions for each day of the week
charging_sessions_by_day = df['Day of Week'].value_counts()

# Plotting the distribution of charging sessions
plt.figure(figsize=(8, 6))
sns.barplot(x=charging_sessions_by_day.index, y=charging_sessions_by_day.values, palette='Purples')

# Add labels and title
plt.title('Distribution of Charging Sessions by Day of the Week', fontsize=14)
plt.xlabel('Day of the Week')
plt.ylabel('Number of Charging Sessions')

# Show the plot
plt.show()
# Out:
# C:\Users\rense\AppData\Local\Temp\ipykernel_16304\1239160141.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=charging_sessions_by_day.index, y=charging_sessions_by_day.values, palette='Purples')

# %% [markdown]
# # Conclusion
# The majority of charging sessions occur on weekdays, with the lowest number observed on Sundays, indicating higher charging demand during workdays.

# %% [markdown]
# # 11.What is the average distance driven since the last charge for different user types?

# %%
# avg_distance_by_user_type = ev_data.groupby('User Type')['Distance Driven (since last charge) (km)'].mean()
# avg_distance_by_user_type
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average distance driven since the last charge for each user type
avg_distance_by_user_type = df.groupby('User Type')['Distance Driven (since last charge) (km)'].mean().reset_index()

# Plotting the average distance driven for different user types
plt.figure(figsize=(8, 6))
sns.barplot(x='User Type', y='Distance Driven (since last charge) (km)', data=avg_distance_by_user_type, palette='Blues')

# Add labels and title
plt.title('Average Distance Driven Since Last Charge by User Type', fontsize=14)
plt.xlabel('User Type')
plt.ylabel('Distance Driven (km)')

# Show the plot
plt.show()
# Out:
# C:\Users\rense\AppData\Local\Temp\ipykernel_16304\3808844927.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='User Type', y='Distance Driven (since last charge) (km)', data=avg_distance_by_user_type, palette='Blues')

# %% [markdown]
# # Conclusion
# Long-distance travelers drive the highest average distance since their last charge, while casual drivers cover the least distance, reflecting distinct charging and driving patterns across user types.

# %% [markdown]
# # 12. How does the average energy consumed differ across vehicle models?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Calculate the average energy consumed for each vehicle model
avg_energy_by_vehicle_model = df.groupby('Vehicle Model')['Energy Consumed (kWh)'].mean().reset_index()

# Sorting the models by average energy consumption for better visualization
avg_energy_by_vehicle_model = avg_energy_by_vehicle_model.sort_values(by='Energy Consumed (kWh)', ascending=False)

# Plotting the average energy consumed for different vehicle models
plt.figure(figsize=(10, 6))
sns.barplot(x='Energy Consumed (kWh)', y='Vehicle Model', data=avg_energy_by_vehicle_model, palette='Greens')

# Add labels and title
plt.title('Average Energy Consumed by Vehicle Model', fontsize=14)
plt.xlabel('Energy Consumed (kWh)')
plt.ylabel('Vehicle Model')

# Show the plot
plt.show()
# Out:
# C:\Users\rense\AppData\Local\Temp\ipykernel_16304\3830615920.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Energy Consumed (kWh)', y='Vehicle Model', data=avg_energy_by_vehicle_model, palette='Greens')

# %% [markdown]
# # Conclusion
# The average energy consumption varies significantly across vehicle models, with certain models consuming noticeably higher energy per charging session, likely due to differences in battery capacity and usage patterns.

# %% [markdown]
# # 13.What is the correlation between the temperature and charging rate?

# %%
# temp_charging_rate_corr = df['Temperature (°C)'].corr(df['Charging Rate (kW)'])
# temp_charging_rate_corr
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot for Temperature vs Charging Rate
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Temperature (°C)', y='Charging Rate (kW)', data=df, color='blue')

# Add labels and title
plt.title('Correlation Between Temperature and Charging Rate', fontsize=14)
plt.xlabel('Temperature (°C)')
plt.ylabel('Charging Rate (kW)')

# Show the plot
plt.show()

# Calculate the Pearson correlation coefficient between Temperature and Charging Rate
correlation = df['Temperature (°C)'].corr(df['Charging Rate (kW)'])
print(f'Correlation: {correlation}')
# Out:
# Correlation: -0.0065883523912901466

# %% [markdown]
# # Conclusion
#  The correlation between temperature and charging rate shows how environmental conditions might influence the efficiency of EV charging, with the specific correlation value revealing the strength and direction of the relationship.

# %% [markdown]
# # 14. Which charging station had the highest number of charging sessions?

# %%
station_with_most_sessions = df['Charging Station ID'].value_counts().idxmax()
station_with_most_sessions
# Out:
# 'Station_108'

# %% [markdown]
# # Conclusion
# It is seen that Station_108 has highest number of charging sessions when compared to all other stations.

# %% [markdown]
# # 15. What is the total energy consumption by each vehicle model?

# %%
# total_energy_by_vehicle_model = df.groupby('Vehicle Model')['Energy Consumed (kWh)'].sum()
# total_energy_by_vehicle_model
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the total energy consumption for each vehicle model
total_energy_by_vehicle_model = df.groupby('Vehicle Model')['Energy Consumed (kWh)'].sum().reset_index()

# Sorting the models by total energy consumption for better visualization
total_energy_by_vehicle_model = total_energy_by_vehicle_model.sort_values(by='Energy Consumed (kWh)', ascending=False)

# Plotting the total energy consumed for different vehicle models
plt.figure(figsize=(10, 6))
sns.barplot(x='Energy Consumed (kWh)', y='Vehicle Model', data=total_energy_by_vehicle_model, palette='Blues')

# Add labels and title
plt.title('Total Energy Consumption by Vehicle Model', fontsize=14)
plt.xlabel('Total Energy Consumed (kWh)')
plt.ylabel('Vehicle Model')

# Show the plot
plt.show()
# Out:
# C:\Users\rense\AppData\Local\Temp\ipykernel_16304\2970529701.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Energy Consumed (kWh)', y='Vehicle Model', data=total_energy_by_vehicle_model, palette='Blues')

# %% [markdown]
# # conclusion
#  The total energy consumption varies significantly across vehicle models, with some models consuming more energy overall due to larger battery sizes or more frequent charging sessions.

# %% [markdown]
# # FINAL CONCLUSION
#
# Conclusion:
# This dataset reveals substantial differences in charging behavior, costs, and environmental factors across various user types, vehicle models, and locations. Key factors like battery capacity, user types, charger preferences, and environmental conditions provide valuable insights into the complexities of EV charging needs and behaviors.
